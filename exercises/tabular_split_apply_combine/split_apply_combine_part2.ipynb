# %% [markdown]
# # Exercise: a second batch of patients
#
# A second batch of patients from the trial was recorded in `predimed_2.csv`. Use the split-apply-combine skills from the previous exercises to answer the two questions below.

# %%
# import libraries
import pandas as pd

# %% [markdown]
# ## Load the data

# %%
df_patients = pd.read_csv('../../data/predimed_smokers.csv')

# %%
df_patients
# Out:
#      patient-id           group    sex_age  smoke_never  smoke_former  \
# 0          1325   MedDiet + VOO    Male_72            0             0
# 1          1326         Control  Female_69            1             0
# 2          1327  MedDiet + Nuts  Female_64            0             1
# 3          1328         Control  Female_70            1             0
# 4          1329   MedDiet + VOO    Male_65            0             1
# ..          ...             ...        ...          ...           ...
# 395        1720   MedDiet + VOO    Male_67            0             0
# 396        1721         Control    Male_68            0             1
# 397        1722   MedDiet + VOO  Female_61            1             0
# 398        1723   MedDiet + VOO  Female_72            1             0
# 399        1724  MedDiet + Nuts  Female_70            1             0
#
#      smoke_current  event
# 0                1      0
# 1                0      0
# 2                0      0
# ...

# %% [markdown]
# ## Question 1: What is the mean age per diet group?

# %%
df_patients.groupby('group')['sex_age']

# %% [markdown]
# ## Question 2: What is the number of cardiovascular events per smoking status

# %%
# your code here

# %% [markdown]
# Something is wrong? What do we need to do to make the commands work?
