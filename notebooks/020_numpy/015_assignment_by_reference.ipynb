# %% [markdown]
# # When one python escapes, they all do!

# %%
# We're setting up a pet shop! We want to keep pythons in terrariums, and parrots in cages
terrarium = ["🐍"]
cage = ["🦜"]

# Everything is well ordered on a shelf
shelf = [terrarium, cage, terrarium, terrarium, cage, terrarium, cage]
shelf
# Out:
# [['🐍'], ['🦜'], ['🐍'], ['🐍'], ['🦜'], ['🐍'], ['🦜']]

# %%
# We can easily access the animals on the shelf...
shelf[2]
# Out:
# ['🐍']

# %%
# Wait a second... a python escaped!
shelf[2].pop()
# Out:
# '🐍'

# %%
# They all have!
shelf
# Out:
# [[], ['🦜'], [], [], ['🦜'], [], ['🦜']]
